# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
train = pd.read_csv("./data/train.csv", sep="###__###",header = None)
test = pd.read_csv("./data/test.csv", sep="###__###",header = None)

# %%
train.columns = ['ID', 'Age', 'Gender', 'Education', 'Query_List']
train.head()
# Out:
#                                  ID  Age  Gender  Education  \
# 0  22DD920316420BE2DF8D6EE651BA174B    1       1          4
# 1  43CC3AF5A8D6430A3B572337A889AFE4    2       1          3
# 2  E97654BFF5570E2CCD433EA6128EAC19    4       1          0
# 3  6931EFC26D229CCFCEA125D3F3C21E57    4       2          3
# 4  E780470C3BB0D340334BD08CDCC3C71A    2       2          4
#
#                                           Query_List
# 0  鏌斿拰鍙屾矡\t濂崇敓\t涓�璐㈢綉棣栭〉 璐㈢粡\thttp://pan.baidu.co...
# 1  骞垮窞鍘ㄥ疂鐑ょ��\t涓栨儏钖�,浜烘儏鎭�,闆ㄩ�侀粍鏄忚姳鏄撹惤,鏅撻�庡共,娉�鐥�...
# 2  閽荤煶涔嬫唱鑰虫満\t鐩橀敠鍒版矆闃�\t鏃呴『鍏�浜�\t杈藉畞闃滄柊杞︾墝\tbaidu...
# 3  鏈�鍙楁�㈣繋鐙楃嫍鎺掕�屾��\t鑸舵�庝箞璇�\t鍦烘櫙鎻� 鍐欒寖渚�\t涓夌淮缁樺浘...
# 4  骞叉Ы鐥囪兘鑷�鎰堝悧\t澶�澶�涓囧瞾鍙惰垝蹇冨幓娌″幓缇庡浗\t骞叉Ы鐥�\t鍙崇溂鐨�...

# %%
test.columns = ['ID', 'Query_List']
test.head()
# Out:
#                                  ID  \
# 0  ED89D43B9F602F96D96C25255F7C228C
# 1  83C3B7B4AAF8074655A8079F561A76D6
# 2  CA9F675A024FB2353849350A35CF8B0F
# 3  DE45B5C4E57AAEBCF3FDFA2A774093BF
# 4  406A681FB3DF81EC0E561796AE50AE50
#
#                                           Query_List
# 0  闄堝�﹀啲灏嗗嚭鐨勪綔鍝�\t鍒樻槉鐒朵笌璋�鏉鹃煹\t211瀛︽牎鐨勫垎鏁扮嚎\t璋佸敱鐨...
# 1  e鐨�0.0052娆℃柟\tqq鎬庝箞蹇�閫熸彁鐜�\t缁濊壊鍊惧煄椋炵儫\t椹�鍏嬫�濅富...
# 2  榛戞殫鏂�\tlpl澶忓�ｈ禌\t澶у瘜璞�鐢电帺鍩�\t鑻遍泟鑱旂洘涔嬬數绔炵О鐜�\t鎵...
# 3  涓�绉嬫按搴撻挀楸�\t楸肩��\t鐢ㄨ毌铓撻挀楸兼�庢牱璋冩紓\t浼犵粺閽�\t3鍙烽奔閽...
# 4  鍙风爜鍚夊嚩\t閫�浼戝共閮ㄦ�诲悗閰嶅伓\t閮�鍘挎湁鍝�浜涘ぇ瀛�\t鑳滃埄娌圭敯灞炰簬...

# %%
test_Nodup=test.drop_duplicates()
test_Nodup=test.dropna()
test_Nodup.head()
# Out:
#                                  ID  \
# 0  ED89D43B9F602F96D96C25255F7C228C
# 1  83C3B7B4AAF8074655A8079F561A76D6
# 2  CA9F675A024FB2353849350A35CF8B0F
# 3  DE45B5C4E57AAEBCF3FDFA2A774093BF
# 4  406A681FB3DF81EC0E561796AE50AE50
#
#                                           Query_List
# 0  闄堝�﹀啲灏嗗嚭鐨勪綔鍝�\t鍒樻槉鐒朵笌璋�鏉鹃煹\t211瀛︽牎鐨勫垎鏁扮嚎\t璋佸敱鐨...
# 1  e鐨�0.0052娆℃柟\tqq鎬庝箞蹇�閫熸彁鐜�\t缁濊壊鍊惧煄椋炵儫\t椹�鍏嬫�濅富...
# 2  榛戞殫鏂�\tlpl澶忓�ｈ禌\t澶у瘜璞�鐢电帺鍩�\t鑻遍泟鑱旂洘涔嬬數绔炵О鐜�\t鎵...
# 3  涓�绉嬫按搴撻挀楸�\t楸肩��\t鐢ㄨ毌铓撻挀楸兼�庢牱璋冩紓\t浼犵粺閽�\t3鍙烽奔閽...
# 4  鍙风爜鍚夊嚩\t閫�浼戝共閮ㄦ�诲悗閰嶅伓\t閮�鍘挎湁鍝�浜涘ぇ瀛�\t鑳滃埄娌圭敯灞炰簬...

# %%
train_Nodup=train.drop_duplicates()
train_Nodup=train.dropna()
train_Nodup.head()
# Out:
#                                  ID  Age  Gender  Education  \
# 0  22DD920316420BE2DF8D6EE651BA174B    1       1          4
# 1  43CC3AF5A8D6430A3B572337A889AFE4    2       1          3
# 2  E97654BFF5570E2CCD433EA6128EAC19    4       1          0
# 3  6931EFC26D229CCFCEA125D3F3C21E57    4       2          3
# 4  E780470C3BB0D340334BD08CDCC3C71A    2       2          4
#
#                                           Query_List
# 0  鏌斿拰鍙屾矡\t濂崇敓\t涓�璐㈢綉棣栭〉 璐㈢粡\thttp://pan.baidu.co...
# 1  骞垮窞鍘ㄥ疂鐑ょ��\t涓栨儏钖�,浜烘儏鎭�,闆ㄩ�侀粍鏄忚姳鏄撹惤,鏅撻�庡共,娉�鐥�...
# 2  閽荤煶涔嬫唱鑰虫満\t鐩橀敠鍒版矆闃�\t鏃呴『鍏�浜�\t杈藉畞闃滄柊杞︾墝\tbaidu...
# 3  鏈�鍙楁�㈣繋鐙楃嫍鎺掕�屾��\t鑸舵�庝箞璇�\t鍦烘櫙鎻� 鍐欒寖渚�\t涓夌淮缁樺浘...
# 4  骞叉Ы鐥囪兘鑷�鎰堝悧\t澶�澶�涓囧瞾鍙惰垝蹇冨幓娌″幓缇庡浗\t骞叉Ы鐥�\t鍙崇溂鐨�...

# %%
import re
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np


Path_train = "./data/train.csv"
Path_test = "./data/test.csv"
lab="###__###"

train = pd.read_csv(Path_train, sep = lab, header = None, encoding = 'utf-8')
test = pd.read_csv(Path_test, sep = lab, header = None, encoding = 'utf-8')

train.columns = ['ID', 'Age', 'Gender', 'Education', 'Query_List']
test.columns = ['ID', 'Query_List']


train_Nodup = train.drop_duplicates()
train_Nodup = train.dropna()

test_Nodup = test.drop_duplicates()
test_Nodup = test.dropna()


#train_QL = train_Nodup['Query_List'].str.split('\t')
#type(train_QL)
#train_Nodup= re.sub(r'[http|https]*://[a-zA-Z0-9.?/&=:]*'," ", train_Nodup)
#train_Nodup.head()

# %%
import re


def Del_web1(data):
    web = re.compile(r'[http|https]*://[a-zA-Z0-9.?/&=:]*', re.S)
    data = re.sub(web, " ", data)
    return data.strip()

def Del_web2(data):
    web = re.compile('ｗｗｗ．', re.S)
    data = re.sub(web, " ", data)
    return data.strip()


train_Nodup['Query_List'] = train_Nodup['Query_List'].apply(lambda x: Del_web1(x))
train_Nodup['Query_List'] = train_Nodup['Query_List'].apply(lambda x: Del_web2(x))

test_Nodup['Query_List'] = test_Nodup['Query_List'].apply(lambda x: Del_web1(x))
test_Nodup['Query_List'] = test_Nodup['Query_List'].apply(lambda x: Del_web2(x))

train_Nodup['Query_List'].head(1)
# Out:
# 0    柔和双沟\t女生\t中财网首页 财经\t \t周公解梦大全查询2345\t曹云金再讽郭德纲\...
# Name: Query_List, dtype: object

# %%
train_Nodup.to_csv("./data/processed_train.csv", header = None, encoding='utf-8')
